# %% [markdown]
# # Data Creation for BLX DB
# #### October 2021
#
# Combine crop data with parcel data to apply APNS to crop polygons
#
# Steps in QGIS to be translated into python:
#
# ~~Load CA_PARCELS_STATEWIDE + i15_Crop_Mapping_2018~~
# ~~ensure both pieces are in the same CRS, I re-projected them to EPSG:3310~~
# ~~Filter CA_PARCELS_STATEWIDE using "County" = 'Kern' → save output as new .shp using \<county>_apns.shp ex: kern_apns.shp~~
# ~~Filter i15_Crop_Mapping_2018 using "COUNTY" = 'Kern'→ save output as new .shp using \<county>_crop.shp ex: kern_crop.shp~~
# ~~Join attributes by location with: kern_crop.shp as the Base Layer, kern_apns.shp as the Join Layer, Geometric predicate: 0 — intersects, Join type: 2 — Take attributes of the feature with largest overlap only (one-to-one~~
#
# ~~Need to map CLASS2 + SUBCLASS2 to more explicit/human readable data using metadata~~

# %%
import fiona
import os
import geopandas as gpd
import pandas as pd

# %%
# !pwd
# Out:
# /home/watermaster/Projects/BLX/GIS/CA_CROP_and_Parcel

# %%
fiona.listlayers('./raw_data/i15_crop_mapping_2018_gdb/i15_crop_mapping_2018.gdb')
# Out:
# ['i15_Crop_Mapping_2018']

# %%
fiona.listlayers('./raw_data/Parcels_CA_2014.gdb/')
# Out:
# ['CA_PARCELS_STATEWIDE_INFO', 'CA_PARCELS_STATEWIDE']

# %%
fiona.listlayers('./raw_data/ca-county-boundaries/CA_Counties/CA_Counties_TIGER2016.dbf')
# Out:
# ['CA_Counties_TIGER2016']

# %% [markdown]
# ## Load in county data to use a mask to chunk other data by individual county.

# %%
gdf_counties = gpd.read_file('./raw_data/ca-county-boundaries/CA_Counties/CA_Counties_TIGER2016.dbf',
                    driver='FileGDB',
                    layer='CA_Counties_TIGER2016')
gdf_counties = gdf_counties.to_crs(3310)

# %%
gdf_kern_county = gdf_counties.loc[gdf_counties['NAME']=='Kern']

# %%
# gdf_kern_county.crs
# gdf_kern_county.plot()

# %% [markdown]
# ## Load in crop data

# %%
gdf_crop = gpd.read_file('./raw_data/i15_crop_mapping_2018_gdb/i15_crop_mapping_2018.gdb',
                    driver='FileGDB',
                    layer='i15_Crop_Mapping_2018',
                    mask = gdf_kern_county)
gdf_crop = gdf_crop.to_crs(3310)

# %%
# gdf_crop.crs
# gdf_crop.plot()
# gdf_crop.columns

# %% [markdown]
# ## Load in parcel data

# %%
gdf_apn = gpd.read_file('./raw_data/Parcels_CA_2014.gdb/',
                        driver='FileGDB',
                        layer='CA_PARCELS_STATEWIDE',
                        mask = gdf_kern_county)
gdf_apn = gdf_apn.to_crs(3310)

# %%
# gdf_apn.crs
# gdf_apn.plot()
# gdf_crop.sindex.valid_query_predicates
# gdf_apn.sindex.valid_query_predicates
# gdf_apn.columns

# %% [markdown]
# ### __gdf_combo__
# (spatial intersectional join of __gdf_crop__ with __gdf_apn__)

# %%
gdf_combo = gpd.sjoin(gdf_crop, gdf_apn, how = 'inner', op = 'intersects')

# %%
# gdf_combo.columns
# gdf_combo.loc[gdf_combo['UniqueID'] == '1509614'].T#.plot() # test crop row

# %% [markdown]
# ### __gdf_over_max__
# (selection of the maximum spatial overlap of __gdf_crop__ with __gdf_apn__,
# practically translates to each __gdf_crop__ row (`uniqueID` is good identifier) being associated with the __gdf_apn__ row (`PARNO` is good identifier) that has the maximum spatial overlap)

# %%
gdf_over = gpd.overlay(gdf_crop, gdf_apn, how = 'intersection')
gdf_over['area_overlap'] = gdf_over.geometry.area
gdf_over_max = gdf_over.loc[gdf_over.groupby('UniqueID')['area_overlap'].agg(pd.Series.idxmax)][['UniqueID','PARNO','area_overlap']]

# %% [markdown]
# ### Merging
# __gdf_combo__ with __gdf_over_max__

# %%
gdf_combo_max_area = gdf_combo.merge(gdf_over_max, left_on = ['UniqueID','PARNO'], right_on = ['UniqueID','PARNO'])

# %%
# gdf_combo_max_area.loc[gdf_combo_max_area['UniqueID'] == '1509614'] # test crop row

# %%
gdf_combo_max_area.CROPTYP2.unique()
# Out:
# array(['X', 'T9', 'D14', 'P1', 'V', 'D1', 'F11', 'T6', 'T10', 'T30',
#        'T18', 'F16', 'YP', 'P6', 'G6', 'D10', 'C7', 'U', 'G2', 'C', 'D12',
#        'T19', 'D5', 'D15', 'F1', 'T31', 'T15', 'T21', 'P3', 'F10', 'T4',
#        'D3', 'T27', 'F2', 'T16', 'D13', 'D16', 'C6', 'C5', 'C4', 'T20'],
#       dtype=object)

# %% [markdown]
# ## Add metadata

# %%
meta_data_dict = pd.read_excel('./crop_metadata.xlsx', sheet_name='formatted',header=None, names =['key', 'value']).set_index('key').T.to_dict('records')[0]
# Out:
# /home/watermaster/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %%
meta_data_dict['G']
# Out:
# 'Grain and hay crops'

# %%
gdf_combo_max_area['crop2018'] = gdf_combo_max_area['CROPTYP2'].map(meta_data_dict)

# %%
gdf_combo_max_area.head().T
# Out:
#                                                                     0  \
# UniqueID                                                      1519857
# DWR_REVISE
# SYMB_CLASS                                                          X
# MULTIUSE                                                            S
# CLASS1                                                             **
# SUBCLASS1                                                          **
# SPECOND1                                                            *
# IRR_TYP1PA                                                          *
# IRR_TYP1PB                                                          *
# PCNT1                                                              **
# CLASS2                                                              X
# SUBCLASS2                                                          **
# SPECOND2                                                            *
# IRR_TYP2PA                                                          *
# IRR_TYP2PB                                                          *
# PCNT2                                                              00
# CLASS3                                                             **
# SUBCLASS3                                                          **
# SPECOND3                                                            *
# IRR_TYP3PA                                                          *
# IRR_TYP3PB                                                          *
# PCNT3                                                              **
# CLASS4                                                             **
# SUBCLASS4                                                          **
# SPECOND4                                                            *
# IRR_TYP4PA                                                          *
# IRR_TYP4PB                                                          *
# PCNT4                                                              **
# UCF_ATT                         S********* X*****00******************
# CROPTYP1                                                         ****
# ADOY1                                                             NaN
# CROPTYP2                                                            X
# ADOY2                                                             NaN
# CROPTYP3                                                         ****
# ADOY3                                                             NaN
# CROPTYP4                                                         ****
# ADOY4                                                             NaN
# REGION                                                            SRO
# ACRES                                                       107.99117
# COUNTY                                                           Kern
# LIQ_REPORT                                        X    **** **** ****
# Shape_Length_left                                            0.031073
# Shape_Area_left                                              0.000043
# geometry            (POLYGON Z ((-17429.81961397751 -265320.405318...
# index_right                                                     45326
# PARNO                                                        05706027
# County                                                           Kern
# ADDRESS                                                          None
# CITY                                                             None
# ZIP                                                              None
# Shape_Length_right                                        1335.938652
# Shape_Area_right                                        105966.426558
# area_overlap                                            105944.435897
# crop2018                            Not cropped or unclassified; None
#
#                                                                     1  \
# UniqueID                                                      1515541
# DWR_REVISE
# SYMB_CLASS                                                          T
# MULTIUSE                                                            S
# CLASS1                                                             **
# SUBCLASS1                                                          **
# SPECOND1                                                            *
# IRR_TYP1PA                                                          *
# IRR_TYP1PB                                                          *
# PCNT1                                                              **
# CLASS2                                                              T
# SUBCLASS2                                                           9
# SPECOND2                                                            *
# IRR_TYP2PA                                                          *
# IRR_TYP2PB                                                          *
# PCNT2                                                              00
# CLASS3                                                             **
# SUBCLASS3                                                          **
# SPECOND3                                                            *
# IRR_TYP3PA                                                          *
# IRR_TYP3PB                                                          *
# PCNT3                                                              **
# CLASS4                                                             **
# SUBCLASS4                                                          **
# SPECOND4                                                            *
# IRR_TYP4PA                                                          *
# IRR_TYP4PB                                                          *
# PCNT4                                                              **
# UCF_ATT                         S********* T 9***00******************
# CROPTYP1                                                         ****
# ADOY1                                                             NaN
# CROPTYP2                                                           T9
# ADOY2                                                           202.0
# CROPTYP3                                                         ****
# ADOY3                                                             NaN
# CROPTYP4                                                         ****
# ADOY4                                                             NaN
# REGION                                                            SRO
# ACRES                                                        19.02655
# COUNTY                                                           Kern
# LIQ_REPORT                                        T9   **** **** ****
# Shape_Length_left                                            0.012125
# Shape_Area_left                                              0.000008
# geometry            (POLYGON Z ((145214.237613245 -321172.29564606...
# index_right                                                    154820
# PARNO                                                        22351011
# County                                                           Kern
# ADDRESS                                                          None
# CITY                                                             None
# ZIP                                                              None
# Shape_Length_right                                        1217.670528
# Shape_Area_right                                         84219.977497
# area_overlap                                             73329.726461
# crop2018            Truck, nursery & berry crops; Melons, squash, ...
#
#                                                                     2  \
# UniqueID                                                      1512576
# DWR_REVISE
# SYMB_CLASS                                                          D
# MULTIUSE                                                            S
# CLASS1                                                             **
# SUBCLASS1                                                          **
# SPECOND1                                                            *
# IRR_TYP1PA                                                          *
# IRR_TYP1PB                                                          *
# PCNT1                                                              **
# CLASS2                                                              D
# SUBCLASS2                                                          14
# SPECOND2                                                            *
# IRR_TYP2PA                                                          *
# IRR_TYP2PB                                                          *
# PCNT2                                                              00
# CLASS3                                                             **
# SUBCLASS3                                                          **
# SPECOND3                                                            *
# IRR_TYP3PA                                                          *
# IRR_TYP3PB                                                          *
# PCNT3                                                              **
# CLASS4                                                             **
# SUBCLASS4                                                          **
# SPECOND4                                                            *
# IRR_TYP4PA                                                          *
# IRR_TYP4PB                                                          *
# PCNT4                                                              **
# UCF_ATT                         S********* D14***00******************
# CROPTYP1                                                         ****
# ADOY1                                                             NaN
# CROPTYP2                                                          D14
# ADOY2                                                             NaN
# CROPTYP3                                                         ****
# ADOY3                                                             NaN
# CROPTYP4                                                         ****
# ADOY4                                                             NaN
# REGION                                                            SRO
# ACRES                                                         4.80295
# COUNTY                                                           Kern
# LIQ_REPORT                                        D14  **** **** ****
# Shape_Length_left                                            0.005694
# Shape_Area_left                                              0.000002
# geometry            (POLYGON Z ((196394.2325934503 -254149.6547569...
# index_right                                                    253396
# PARNO                                                        35236004
# County                                                           Kern
# ADDRESS                                                          None
# CITY                                                             None
# ZIP                                                              None
# Shape_Length_right                                          407.87101
# Shape_Area_right                                         10394.468391
# area_overlap                                              9595.552669
# crop2018                        Deciduous fruits and nuts; Pistachios
#
#                                                                     3  \
# UniqueID                                                      1515669
# DWR_REVISE
# SYMB_CLASS                                                          D
# MULTIUSE                                                            S
# CLASS1                                                             **
# SUBCLASS1                                                          **
# SPECOND1                                                            *
# IRR_TYP1PA                                                          *
# IRR_TYP1PB                                                          *
# PCNT1                                                              **
# CLASS2                                                              D
# SUBCLASS2                                                          14
# SPECOND2                                                            *
# IRR_TYP2PA                                                          *
# IRR_TYP2PB                                                          *
# PCNT2                                                              00
# CLASS3                                                             **
# SUBCLASS3                                                          **
# SPECOND3                                                            *
# IRR_TYP3PA                                                          *
# IRR_TYP3PB                                                          *
# PCNT3                                                              **
# CLASS4                                                             **
# SUBCLASS4                                                          **
# SPECOND4                                                            *
# IRR_TYP4PA                                                          *
# IRR_TYP4PB                                                          *
# PCNT4                                                              **
# UCF_ATT                         S********* D14***00******************
# CROPTYP1                                                         ****
# ADOY1                                                             NaN
# CROPTYP2                                                          D14
# ADOY2                                                             NaN
# CROPTYP3                                                         ****
# ADOY3                                                             NaN
# CROPTYP4                                                         ****
# ADOY4                                                             NaN
# REGION                                                            SRO
# ACRES                                                         0.91497
# COUNTY                                                           Kern
# LIQ_REPORT                                        D14  **** **** ****
# Shape_Length_left                                            0.002553
# Shape_Area_left                                                   0.0
# geometry            (POLYGON Z ((196356.2806880391 -254184.5322515...
# index_right                                                    253394
# PARNO                                                        35236002
# County                                                           Kern
# ADDRESS                                                          None
# CITY                                                             None
# ZIP                                                              None
# Shape_Length_right                                         588.361301
# Shape_Area_right                                         19325.642499
# area_overlap                                               3450.44675
# crop2018                        Deciduous fruits and nuts; Pistachios
#
#                                                                     4
# UniqueID                                                      1515677
# DWR_REVISE
# SYMB_CLASS                                                          P
# MULTIUSE                                                            S
# CLASS1                                                             **
# SUBCLASS1                                                          **
# SPECOND1                                                            *
# IRR_TYP1PA                                                          *
# IRR_TYP1PB                                                          *
# PCNT1                                                              **
# CLASS2                                                              P
# SUBCLASS2                                                           1
# SPECOND2                                                            *
# IRR_TYP2PA                                                          *
# IRR_TYP2PB                                                          *
# PCNT2                                                              00
# CLASS3                                                              X
# SUBCLASS3                                                          **
# SPECOND3                                                            *
# IRR_TYP3PA                                                          *
# IRR_TYP3PB                                                          *
# PCNT3                                                              00
# CLASS4                                                             **
# SUBCLASS4                                                          **
# SPECOND4                                                            *
# IRR_TYP4PA                                                          *
# IRR_TYP4PB                                                          *
# PCNT4                                                              **
# UCF_ATT                         S********* P 1***00 X*****00*********
# CROPTYP1                                                         ****
# ADOY1                                                             NaN
# CROPTYP2                                                           P1
# ADOY2                                                           -23.0
# CROPTYP3                                                            X
# ADOY3                                                           163.0
# CROPTYP4                                                         ****
# ADOY4                                                             NaN
# REGION                                                            SRO
# ACRES                                                        74.00867
# COUNTY                                                           Kern
# LIQ_REPORT                                        P1   X    **** ****
# Shape_Length_left                                            0.022935
# Shape_Area_left                                               0.00003
# geometry            (POLYGON Z ((156482.0880087817 -345222.6919008...
# index_right                                                    228118
# PARNO                                                        31501118
# County                                                           Kern
# ADDRESS                                                          None
# CITY                                                             None
# ZIP                                                              None
# Shape_Length_right                                        3191.285477
# Shape_Area_right                                        635190.435053
# area_overlap                                            299502.481002
# crop2018                          Pasture; Alfalfa & alfalfa mixtures
